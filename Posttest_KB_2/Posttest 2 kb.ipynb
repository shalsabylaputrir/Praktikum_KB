# %%
import pandas as pd 
from tabulate import tabulate

# %% [markdown]
# df = pd.read_csv("protein_classification_46k_ngrams.csv")

# %% [markdown]
# ## Informasi yang didapatkan adalah jumlah record, nama attribute, jumlah attribute dengan tipe objek, jumlah attribute dengan tipe
# ## angka, jumlah attribute yang memiliki nilai null.

# %%
#jJumlah record
Jumlah = len(df)
print(Jumlah)

# nama atribut
nama = list(df.columns)
print(nama)

# jumlah atribut tipe objek
jumlahObjek = len(df.dtypes[df.dtypes == 'object'])
print(jumlahObjek)

# jumlah atribut tipe angka
jumlahAngka =len(df.dtypes[df.dtypes == 'int64'])
print(jumlahAngka)

#jumlah atribut nilai null
df.isna().any().sum()

# %% [markdown]
# ## Masukkan informasi di atas dalam dictionary dengan key sesuai nama informasinya. Tampilkan isi dari dictionary tersebut sebagus mungkin.

# %%
# Jumlah record
Jumlah = len(df)

#nama Atribut
nama = list(df.columns)
nama = ",\n".join(nama)

#jumlah atribut tipe objek
jumlahObjek = len(df.dtypes[df.dtypes == 'object'])

#jumlah atribut tipe angka
jumlahAngka = len(df.dtypes[df.dtypes == 'int64'])

#jumlah atribut nilai null
jumlahNull = df.isna().any().sum()

kamus = {
    "Jumlah Record":[Jumlah],
    "Nama Atribut" : [nama],
    "Jumlah atribut tipe objek" : [jumlahObjek],
    "Jumlah atribut tipe angka" : [jumlahAngka],
    "Jumlah atribut nilai null"  : [jumlahNull],
    
}

tab = pd.DataFrame(kamus)
print(tabulate(tab, headers='keys', tablefmt='psql',showindex=False))
# Out:
# +-----------------+---------------------------+-----------------------------+-----------------------------+-----------------------------+
# |   Jumlah Record | Nama Atribut              |   Jumlah atribut tipe objek |   Jumlah atribut tipe angka |   Jumlah atribut nilai null |
# |-----------------+---------------------------+-----------------------------+-----------------------------+-----------------------------|
# |           46422 | structureId,              |                           4 |                           1 |                           0 |
# |                 | classification,           |                             |                             |                             |
# |                 | residueCount,             |                             |                             |                             |
# |                 | resolution,               |                             |                             |                             |
# |                 | structureMolecularWeight, |                             |                             |                             |
# |                 | crystallizationTempK,     |                             |                             |                             |
# |                 | densityMatthews,          |                             |                             |                             |
# |                 | densityPercentSol,        |                             |                             |                             |
# |                 | phValue,                  |                             |                             |                             |
# |                 | sequence,                 |                             |                             |                             |
# |                 | 3mers                     |                             |                             |                             |
# +-----------------+---------------------------+-----------------------------+-----------------------------+-----------------------------+

# %% [markdown]
# ## Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka.

# %%
df.describe()
# Out:
#        residueCount    resolution  structureMolecularWeight  \
# count  46422.000000  46422.000000              4.642200e+04
# mean     858.969907      2.186390              9.730842e+04
# std     1331.761893      0.583336              1.512602e+05
# min        6.000000      0.480000              7.447300e+02
# 25%      296.000000      1.800000              3.376576e+04
# 50%      506.000000      2.100000              5.727849e+04
# 75%      916.000000      2.500000              1.031324e+05
# max    57792.000000      9.010000              4.921404e+06
#
#        crystallizationTempK  densityMatthews  densityPercentSol       phValue
# count          46422.000000     46422.000000       46422.000000  46422.000000
# mean             291.044358         2.704024          51.934464      6.800570
# std                8.547038         0.732436          10.076324      1.352036
# min                4.000000         0.000000           0.000000      0.000000
# 25%              290.000000         2.230000          44.900000      6.000000
# 50%              293.000000         2.520000          51.070000      7.000000
# 75%              295.000000         2.950000          58.240000      7.500000
# max              398.000000        12.700000          90.330000    100.000000

# %% [markdown]
# ## Tampilkan nilai korelasi attribute bertipe angka.

# %%
df.corr()
# Out:
#                           residueCount  resolution  structureMolecularWeight  \
# residueCount                  1.000000    0.393486                  0.986755
# resolution                    0.393486    1.000000                  0.401501
# structureMolecularWeight      0.986755    0.401501                  1.000000
# crystallizationTempK          0.003807    0.002202                 -0.000777
# densityMatthews               0.195011    0.493781                  0.200696
# densityPercentSol             0.213963    0.489176                  0.218466
# phValue                       0.023918    0.033204                  0.023445
#
#                           crystallizationTempK  densityMatthews  \
# residueCount                          0.003807         0.195011
# resolution                            0.002202         0.493781
# structureMolecularWeight             -0.000777         0.200696
# crystallizationTempK                  1.000000        -0.049455
# densityMatthews                      -0.049455         1.000000
# densityPercentSol                    -0.053783         0.922359
# phValue                              -0.002747         0.003305
#
#                           densityPercentSol   phValue
# residueCount                       0.213963  0.023918
# resolution                         0.489176  0.033204
# structureMolecularWeight           0.218466  0.023445
# crystallizationTempK              -0.053783 -0.002747
# densityMatthews                    0.922359  0.003305
# densityPercentSol                  1.000000  0.006053
# phValue                            0.006053  1.000000

# %% [markdown]
# ## Rubah nilai salah satu attribute bertipe angka menjadi desimal 3 angka dibelakang koma jika tidak ada, lakukan sebaliknya (dari desimal menjadi bilangan bulat).

# %%
df["structureMolecularWeight"].head()

df["structureMolecularWeight"] = df["structureMolecularWeight"] * 0.00

df["structureMolecularWeight"].head()
# Out:
# 0    217.68959
# 1     42.70755
# 2     40.65850
# 3      8.17572
# 4     82.84997
# Name: structureMolecularWeight, dtype: float64

# %% [markdown]
# ## Tampilkan 10 record pertama dari attribute bertipe angka.

# %%
dfAngka= df.select_dtypes(include=['float64','int64'])

dfAngka.head(10)
# Out:
#    residueCount  resolution  structureMolecularWeight  crystallizationTempK  \
# 0          2012      0.0021                 217.68959                 287.0
# 1           382      0.0020                  42.70755                 277.0
# 2           374      0.0026                  40.65850                 277.0
# 3            70      0.0017                   8.17572                 277.0
# 4           735      0.0021                  82.84997                 277.0
# 5           305      0.0020                  35.88088                 277.0
# 6           305      0.0020                  35.88088                 277.0
# 7           305      0.0020                  35.88088                 277.0
# 8           248      0.0017                  28.43101                 289.0
# 9           240      0.0018                  26.05850                 293.0
#
#    densityMatthews  densityPercentSol  phValue
# 0             2.43              41.00      7.5
# 1             2.97              59.00      5.0
# 2             2.30              46.82      8.4
# 3             2.21              43.80      8.0
# 4             2.30              47.00      6.0
# 5             2.66              53.69      7.0
# 6             2.66              53.69      7.0
# 7             2.66              53.69      7.0
# 8             2.20              48.00      5.5
# 9             2.29              46.18      7.5

# %% [markdown]
# ## Simpan dataset dengan attribute bertipe angka ke dalam file CSV.

# %%
dfAngka.to_csv("Posttest2.csv", index=False)
